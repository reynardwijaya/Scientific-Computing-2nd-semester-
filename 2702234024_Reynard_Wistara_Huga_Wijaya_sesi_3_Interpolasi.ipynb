# %% [markdown]
# <a href="https://colab.research.google.com/github/reynardwijaya/Scientific-Computing-2nd-semester-/blob/main/2702234024_Reynard_Wistara_Huga_Wijaya_sesi_3_Interpolasi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from scipy.interpolate import interp1d
from scipy.interpolate import CubicSpline
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('seaborn-poster')
# Out:
# <ipython-input-1-6b6b9e931396>:5: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-poster')

# %% [markdown]
# Linear Interpolation

# %%
x = [0, 1, 2, 3, 4, 5]
y = [1,3, 3, 5, 2, 2]

# %%
f = interp1d(x,y)

x_lin = np.linspace(0,5,100)
y_lin = f(x_lin)

y_ask = f(3.1)
print (y_ask)
# Out:
# 4.699999999999999

# %%
plt.plot(x,y,'ob')
plt.plot(x_lin, y_lin, 'b')
plt.plot(3.1,f(3.1), 'ro')
plt.show()

# %% [markdown]
# Newtown interpolation

# %%
import numpy as np
import matplotlib.pyplot as plt

plt.style.use('seaborn-poster')

# %matplotlib inline
def divided_diff(x,y):
  n = len(y)
  coef = np.zeros([n,n])
  #the first column is y
  coef[:,0] = y

  for  j in range(1,n):
   for i in range(n-j):
     coef[i][j] = \
     (coef[i+1][j-1] - coef[i][j-1]) / (x[i+j]-x[i])

  return coef

def newton_poly(coef, x_data, x):
  n = len(x_data) - 1
  p = coef[n]
  for k in range (1, n+1):
    p = coef[n-k] +(x - x_data[n-k])*p
  return p
# Out:
# <ipython-input-19-03bbdffd85f5>:4: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-poster')

# %%
x = np.array([-5, -1, 0, 2])
y = np.array([-2, 6, 1, 3])

a_s = divided_diff(x,y)[0,:]

x_new = np.arange(-5, 2.1, .1)
y_new = newton_poly(a_s, x, x_new)

plt.figure(figsize = (12, 8))
plt.plot(x, y, 'bo')
plt.plot(x_new, x_new, 'go')
plt.plot(x_new, y_new)

# %% [markdown]
# Cubic Spline Interpolation

# %%
x = [0, 1, 2, 3, 4, 5]
y = [1, 3, 3, 5, 2, 2]

# %%
f = CubicSpline(x,y,bc_type='natural')

x_cub = np.linspace(0,5,100)
y_cub = f(x_cub)

y_ask = f(2.9)
print(y_ask)
# Out:
# 5.000368421052631

# %%
plt.plot(x,y,'bo')
plt.plot(x_cub,y_cub,'b')
plt.plot(2.9,f(2.9),'ro')
plt.show()

# %% [markdown]
# Olympiade tahun 1990, juara lomba sprint 100 m adalah Ben Johnson. Catatan larinya ketika 0 detik kecepatannya adalah 10m/detik. Pada saat 5 meter Kecepatannta adalah 15m/detik. Pada saat 10m kecepatannya adalah 20m/detik. Berapa kecepatan larinya saat pada jarak 7.2m?
# Jawablah menggunakan coding python linier interpolation di bawah

# %%
import numpy as np
import matplotlib.pyplot as plt

plt.style.use('seaborn-poster')

# %matplotlib inline
def divided_diff(x,y):
  n = len(y)
  coef = np.zeros([n,n])
  #the first column is y
  coef[:,0] = y

  for  j in range(1,n):
   for i in range(n-j):
     coef[i][j] = \
     (coef[i+1][j-1] - coef[i][j-1]) / (x[i+j]-x[i])

  return coef

def newton_poly(coef, x_data, x):
  n = len(x_data) - 1
  p = coef[n]
  for k in range (1, n+1):
    p = coef[n-k] +(x - x_data[n-k])*p
  return p
# Out:
# <ipython-input-25-03bbdffd85f5>:4: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-poster')

# %%
x = np.array([0, 5, 10])
y = np.array([10, 15, 20])

a_s = divided_diff(x,y)[0,:]

x_new = np.arange(-5, 2.1, .1)
y_new = newton_poly(a_s, x, x_new)

plt.figure(figsize = (12, 8))
plt.plot(x, y, 'bo')
plt.plot(x_new, x_new, 'go')
plt.plot(x_new, y_new)

# %%
x = [0, 5, 10]
y = [10, 15, 20]

# %%
f = interp1d(x,y)

x_lin = np.linspace(0,10,100)
y_lin = f(x_lin)

y_ask = f(3.1)
print (y_ask)
# Out:
# 13.1

# %%
plt.plot(x,y,'ob')
plt.plot(x_lin, y_lin, 'b')
plt.plot(3.1,f(3.1), 'ro')
plt.show()
